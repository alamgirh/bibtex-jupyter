# %% [markdown]
# # Quadratic Equations
# When $a \ne 0$, quadratic equation <cite data-cite="anton2002calculus">(Anton, 2002)</cite>
# $$ ax^2 + bx + c = 0 $$
# has two roots and they are
# $$x = {-b \pm \sqrt{b^2-4ac} \over 2a}.$$

# %% [markdown]
# ## Type of roots
# - $d = b^2-4ac$;  (comment about roots)
# - $d \ge 0$;  roots are real
#  - $d > 0$; roots are real and distinct
#  - $d = 0$; roots are real and same
# - $d<0$; roots are complex

# %% [markdown]
# ## Vertex of Parabola
# $$ \begin{array}{rcl}
# y & = & a x^{2}+bx+c\\
#   & = & a\left(x^{2}+2\times\frac{b}{2a}x+\frac{c}{a}\right)\\
#   & = & a\left(x+\frac{b}{2a}\right)^2 - \frac{b^2}{4a} + c
# \end{array}$$
#
# Vertex of the parabola, $y = f(x)$ is $\left(-\frac{b}{2a}, c - \frac{b^2}{4a}\right)$.

# %% [markdown]
# ## Table: Type of roots
#  | $d = b^2-4ac$     | comment about roots         |
#  |-------------------|-----------------------------|
#  | $d>0$             | roots are real and distinct |
#  | $d = 0$           | roots are real and same     |
#  | $d<0$             | roots are complex           |

# %% [markdown]
# ## Plots using Python
# ![LaTex: Quadratic Functions](quadraticplots.png)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-3, 3, 100)

def f(x,a,b,c):
   return a*x**2+b*x+c;

def vertex(a,b,c):
   x0 = -b/(2.0*a)
   y0 = c-b*b/(4.0*a)
   return [x0, y0];
print vertex(1,0,-1)
# Out:
# [0.0, -1.0]

# %%
plt.plot(x, f(x,1,1,1), label='$y=x^{2}+x+1$',color='red')
plt.plot(x, f(x,1,1,-2), label='$y=x^{2}+x-2$',color='green')
plt.plot(x, f(x,1,-2,1), label='$y=x^{2}-2x+1$',color='blue')
a1, b1 = vertex(1,1,1)
plt.plot([a1],[b1], 'ro')
a2, b2 = vertex(1,1,-2)
plt.plot([a2],[b2], 'go')
a3, b3 = vertex(1,-2,1)
plt.plot([a3],[b3], 'bo')

plt.axis('equal')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.title("Quadratic Functions")
plt.annotate('(0, 0)', xy=(0, 0), xytext=(.1, -.3))
plt.axis([-3, 3, -3, 3])
plt.legend(bbox_to_anchor=(1, .4))
plt.show()
